# %% [markdown]
# <a href="https://colab.research.google.com/github/spike1spike/University/blob/main/Practice/Practice_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа №3. Введение в ООП**

# %% [markdown]
# ## **Задание №1. Создайте класс Sphere для представления сферы в трехмерном пространстве**

# %% [markdown]
# Обеспечьте следующие методы класса:
#
# 1. Конструктор, принимающий 4 действительных числа: радиус, и 3 координаты центра шара. Если конструктор вызывается без аргументов, создать объект сферы с единичным радиусом и центром в начале координат. Если конструктор вызывается с аргументом, создать объект сферы с соответствующим радиусом и центром в начале координат.
#
# 2. Метод get_volume (), который возвращает действительное число — объем шара, ограниченной текущей сферой.
#
# 3. Метод get_square (), который возвращает действительное число — площадь внешней поверхности сферы.
#
# 4. Метод get_radius (), который возвращает действительное число — радиус сферы.
#
# 5. Метод get_center (), который возвращает тьюпл с 3 действительными числами — координатами центра сферы в том же порядке, в каком они задаются в конструкторе.
#
# 6. Метод set_radius (r), который принимает 1 аргумент — действительное число, и меняет радиус текущей сферы, ничего не возвращая.
#
# 7. Метод set_center (x, y, z), который принимает 3 аргумента — действительных числа, и меняет координаты центра сферы, ничего не возвращая. Координаты задаются в том же порядке, что и в конструкторе.
#
# 8. Метод is_point_inside (x, y, z), который принимает 3 аргумента — действительных числа — координаты некоторой точки в пространстве (в том же порядке, что и в конструкторе), и возвращает логическое значение True или False в зависимости от того, находится эта точка внутри сферы.

# %%
# Тесты

s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6

# %%
class Sphere:
    '''Класс объектов сфер'''

    def __init__(self, radius=1.0, xO=0.0, yO=0.0, zO=0.0):
        self.__radius = radius
        self.__center_x = xO
        self.__center_y = yO
        self.__center_z = zO

    def get_volume(self):
        from math import pi

        return (4/3)*pi*(self.__radius**3)
    def get_square(self):
        from math import pi

        return 4*pi*(self.__radius**2)
    def get_radius(self):
        return self.__radius
    def get_center(self):
        centre = (self.__center_x, self.__center_y, self.__center_z)

        return centre
    def set_radius(self, r):
        self.__radius = r
    def set_center(self, x, y, z):
        self.__center_x = x
        self.__center_y = y
        self.__center_z = z
    def is_point_inside(self, x, y, z):
        inside_bool = (self.__center_x-self.__radius <= x <= self.__center_x+self.__radius) and \
        (self.__center_y-self.__radius <= y <= self.__center_y+self.__radius) and \
        (self.__center_z-self.__radius <= z <= self.__center_z+self.__radius)

        return inside_bool


# Тесты
s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6
# Out:
# (0.0, 0.0, 0.0)
# 0.5235987755982988
# False
# True
# 1.6

# %% [markdown]
# ## **Задание №2. Создайте класс SuperStr, который наследует стандартный класс str и содержит 2 новых метода:**

# %% [markdown]
# 1. Метод is_repeatance (s), который принимает 1 аргумент s и возвращает True или False в зависимости от того, может ли текущая строку быть получена целым количеством повторов строки s. Вернуть False, если s не является строкой. Считать, что пустая строка не содержит повторов.
#
# 2. Метод is_palindrom (), который возвращает True или False в зависимости от того, является ли строка [палиндромом](https://ru.wikipedia.org/wiki/Палиндром). Регистрами символов пренебрегать. Пустую строку считать палиндромом.

# %%
class SuperStr(str):
    '''Класс строки с расширенными возможностями'''

    def is_repeatance(self, s):
        if (self == '') or (type(s) != str):
            return False
        if len( self.replace(s, '') ) == 0:
            return True
        return False

    def is_palindrom(self):
        if self.lower() == ( self.lower() [::-1] ):
            return True
        return False

# %%
# Тесты

s = SuperStr("123123123123")
print(s.is_repeatance("123")) # True
print(s.is_repeatance("123123")) # True
print(s.is_repeatance("123123123123")) # True
print(s.is_repeatance("12312")) # False
print(s.is_repeatance(123)) # False
print(s.is_palindrom()) # False
print(s) # 123123123123 (строка)
print(int(s)) # 123123123123 (целое число)
print(s + "qwe") # 123123123123qwe
p = SuperStr("123_321")
print(p.is_palindrom()) # True
# Out:
# True
# True
# True
# False
# False
# False
# 123123123123
# 123123123123
# 123123123123qwe
# True

# %% [markdown]
# ## **Задание №3. В коде ниже представлен класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой).**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender')
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}

# %% [markdown]
# ### **3.1. Наследование**

# %% [markdown]
# * Класс Mentor должен стать родительским классом для преподавателей. От него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).
#
# > Имя, фамилю и список закрепленных курсов логично реализовать на уровне родительского класса.

# %%
class Student:
    '''Класс студентов'''

    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def set_courses_in_progress(self, courses_in_progress):
        if type(courses_in_progress) == list:
            self.courses_in_progress = courses_in_progress
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список курсов в процессе обучения: {courses_in_progress}')

    def set_finished_courses(self, finished_courses):
        if type(finished_courses) == list:
            self.finished_courses = finished_courses
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список завершенных курсов: {finished_courses}')

    def finish_course(self, course_name):
        if course_name in self.courses_in_progress:
            self.courses_in_progress.remove(course_name)
            self.finished_courses.append(course_name)
        else:
            raise ValueError(f'❌ Ошибка: Невозможно добавить завершенный курс: {course_name}')

class Mentor:
    '''Базовый класс преподавателей'''

    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def set_courses_attached(self, courses_attached):
        if type(courses_attached) == list:
            self.courses_attached = courses_attached
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список закрепленных курсов: {courses_attached}')

class Lecturer(Mentor):
    '''Класс лекторов'''

    def __init__(self, name, surname):
        super().__init__(name, surname)

class Reviewer(Mentor):
    '''Класс проверяющих'''

    def __init__(self, name, surname):
        super().__init__(name, surname)

# %% [markdown]
# ### **3.2. Атрибуты и взаимодействие классов**

# %% [markdown]
# * Реализуйте возможность проставления оценок студентам только Reviewer-ам (реализуйте такой метод).
#
# * Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент (реализовать проверку).

# %%
def check_grade(grade) -> bool:
    '''Функция проверяет значение оценки на корректность'''

    try:
        if not(1 <= grade <= 10):
            raise ValueError(f'❌ Ошибка: Оценка должна находиться в пределах [1 10]: {grade}')
    except TypeError:
        raise TypeError(f'❌ Ошибка: Оценка не является числом: {grade}')

    return True

class Student:
    '''Класс студентов'''

    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def set_courses_in_progress(self, courses_in_progress):
        if type(courses_in_progress) == list:
            self.courses_in_progress = courses_in_progress
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список курсов в процессе обучения: {courses_in_progress}')

    def set_finished_courses(self, finished_courses):
        if type(finished_courses) == list:
            self.finished_courses = finished_courses
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список завершенных курсов: {finished_courses}')

    def finish_course(self, course_name):
        if course_name in self.courses_in_progress:
            self.courses_in_progress.remove(course_name)
            self.finished_courses.append(course_name)
        else:
            raise ValueError(f'❌ Ошибка: Невозможно добавить завершенный курс: {course_name}')

    def rate_lecturer(self, lecturer, course, grade):
        if not( (course in lecturer.courses_attached) and (course in self.courses_in_progress) ):
            raise ValueError(f'❌ Ошибка: Невозможно поставить оценку по курсу: {course}')
        if not check_grade(grade):
            return

        if course not in lecturer.grades:
            lecturer.grades[course] = []
        lecturer.grades[course].append(grade)

class Mentor:
    '''Базовый класс преподавателей'''

    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def set_courses_attached(self, courses_attached):
        if type(courses_attached) == list:
            self.courses_attached = courses_attached
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список закрепленных курсов: {courses_attached}')

class Lecturer(Mentor):
    '''Класс лекторов'''

    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

class Reviewer(Mentor):
    '''Класс проверяющих'''

    def __init__(self, name, surname):
        super().__init__(name, surname)

    def rate_hw(self, student, course, grade):
        if not( (course in self.courses_attached) and (course in student.courses_in_progress) ):
            raise ValueError(f'❌ Ошибка: Невозможно поставить оценку по курсу: {course}')
        check_grade(grade)

        if course not in student.grades:
            student.grades[course] = []
        student.grades[course].append(grade)

# %% [markdown]
# ### **3.3. Полиморфизм и магические методы**

# %% [markdown]
# Перегрузите магический метод \_\_str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
#
#
# ```
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# ```
#
# У лекторов:
#
#
#
# ```
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# ```
#
# А у студентов так:
#
#
#
# ```
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ```

# %%
def check_grade(grade) -> bool:
    '''Функция проверяет значение оценки на корректность'''

    try:
        if not(1 <= grade <= 10):
            raise ValueError(f'❌ Ошибка: Оценка должна находиться в пределах [1 10]: {grade}')
    except TypeError:
        raise TypeError(f'❌ Ошибка: Оценка не является числом: {grade}')

    return True

def calc_avg_grade(grades: dict):
    '''Функция вычисляет среднее арифмитическое оценок
    :return avg_grade: Возвращает среднее арифмитическое оценок'''

    if grades:
        grades_ll = list(grades.values())
        avg_grade = sum( sum(grade_l) for grade_l in grades_ll ) / sum( len(grade_l) for grade_l in grades_ll )
    else:
        avg_grade = -1

    return avg_grade


class Student:
    '''Класс студентов'''

    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.courses_in_progress = []
        self.finished_courses = []
        self.grades = {}
        self.avg_grade = -1

    def __str__(self):
        msg = f'''Имя: {self.name}
Фамилия: {self.surname}
Средняя оценка за домашние задания: {round(self.avg_grade, 2)}
Курсы в процессе изучения: {( ', '.join(self.courses_in_progress) ).strip()}
Завершенные курсы: {( ', '.join(self.finished_courses) ).strip()}'''
        return msg

    def set_courses_in_progress(self, courses_in_progress):
        if type(courses_in_progress) == list:
            self.courses_in_progress = courses_in_progress
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список курсов в процессе обучения: {courses_in_progress}')

    def set_finished_courses(self, finished_courses):
        if type(finished_courses) == list:
            self.finished_courses = finished_courses
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список завершенных курсов: {finished_courses}')

    def set_avg_grade(self):
        self.avg_grade = calc_avg_grade(self.grades)

    def finish_course(self, course_name):
        if course_name in self.courses_in_progress:
            self.courses_in_progress.remove(course_name)
            self.finished_courses.append(course_name)
        else:
            raise ValueError(f'❌ Ошибка: Невозможно добавить завершенный курс: {course_name}')

    def rate_lecturer(self, lecturer, course, grade):
        if not( (course in lecturer.courses_attached) and (course in self.courses_in_progress) ):
            raise ValueError(f'❌ Ошибка: Невозможно поставить оценку по курсу: {course}')
        if not check_grade(grade):
            return

        if course not in lecturer.grades:
            lecturer.grades[course] = []
        lecturer.grades[course].append(grade)
        lecturer.set_avg_grade()

class Mentor:
    '''Базовый класс преподавателей'''

    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def set_courses_attached(self, courses_attached):
        if type(courses_attached) == list:
            self.courses_attached = courses_attached
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список закрепленных курсов: {courses_attached}')

class Lecturer(Mentor):
    '''Класс лекторов'''

    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}
        self.avg_grade = -1

    def __str__(self):
        msg = f'''Имя: {self.name}
Фамилия: {self.surname}
Средняя оценка за лекции: {round(self.avg_grade, 2)}'''
        return msg

    def set_avg_grade(self):
        self.avg_grade = calc_avg_grade(self.grades)


class Reviewer(Mentor):
    '''Класс проверяющих'''

    def __init__(self, name, surname):
        super().__init__(name, surname)

    def __str__(self):
        msg = f'''Имя: {self.name}
Фамилия: {self.surname}'''
        return msg

    def rate_hw(self, student, course, grade):
        if not( (course in self.courses_attached) and (course in student.courses_in_progress) ):
            raise ValueError(f'❌ Ошибка: Невозможно поставить оценку по курсу: {course}')
        check_grade(grade)

        if course not in student.grades:
            student.grades[course] = []
        student.grades[course].append(grade)
        student.set_avg_grade()

# %% [markdown]
# **Реализуйте перегрузку других магических методов на Ваш выбор (не менее трёх), руководствуясь по смыслу контекстом представленных классов (студенты, преподаватели, оценки и т.д.)**

# %%
def check_grade(grade) -> bool:
    '''Функция проверяет значение оценки на корректность'''

    try:
        if not(1 <= grade <= 10):
            raise ValueError(f'❌ Ошибка: Оценка должна находиться в пределах [1 10]: {grade}')
    except TypeError:
        raise TypeError(f'❌ Ошибка: Оценка не является числом: {grade}')

    return True

def calc_avg_grade(grades: dict):
    '''Функция вычисляет среднее арифмитическое оценок
    :return avg_grade: Возвращает среднее арифмитическое оценок'''

    if grades:
        grades_ll = list(grades.values())
        avg_grade = sum( sum(grade_l) for grade_l in grades_ll ) / sum( len(grade_l) for grade_l in grades_ll )
    else:
        avg_grade = -1

    return avg_grade

def calc_k_grades(grades: dict) -> int:
    '''Функция вычисляет количество оценок
    :return k_grades: Возвращает количество оценок'''

    grades_ll = list(grades.values())
    k_grades = sum( len(grade_l) for grade_l in grades_ll )

    return k_grades


class Student:
    '''Класс студентов'''

    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.courses_in_progress = []
        self.finished_courses = []
        self.grades = {}
        self.avg_grade = -1

    def __str__(self):
        msg = f'''Имя: {self.name}
Фамилия: {self.surname}
Средняя оценка за домашние задания: {round(self.avg_grade, 2)}
Курсы в процессе изучения: {( ', '.join(self.courses_in_progress) ).strip()}
Завершенные курсы: {( ', '.join(self.finished_courses) ).strip()}'''
        return msg

    def __bool__(self):
        k_grades = calc_k_grades(self.grades)
        if (k_grades >= 10) and (self.avg_grade >= 6):
            return True
        else:
            return False

    def __eq__(self, other):
        if ( sorted(self.courses_in_progress) == sorted(other.courses_in_progress) ) \
        and ( sorted(self.finished_courses) == sorted(other.finished_courses) ):
            return True
        else:
            return False

    def __add__(self, other):
        return self.avg_grade + other.avg_grade

    def __len__(self):
        k_grades = calc_k_grades(self.grades)
        return k_grades

    def set_courses_in_progress(self, courses_in_progress):
        if type(courses_in_progress) == list:
            self.courses_in_progress = courses_in_progress
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список курсов в процессе обучения: {courses_in_progress}')

    def set_finished_courses(self, finished_courses):
        if type(finished_courses) == list:
            self.finished_courses = finished_courses
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список завершенных курсов: {finished_courses}')

    def set_avg_grade(self):
        self.avg_grade = calc_avg_grade(self.grades)

    def finish_course(self, course_name):
        if course_name in self.courses_in_progress:
            self.courses_in_progress.remove(course_name)
            self.finished_courses.append(course_name)
        else:
            raise ValueError(f'❌ Ошибка: Невозможно добавить завершенный курс: {course_name}')

    def rate_lecturer(self, lecturer, course, grade):
        if not( (course in lecturer.courses_attached) and (course in self.courses_in_progress) ):
            raise ValueError(f'❌ Ошибка: Невозможно поставить оценку по курсу: {course}')
        if not check_grade(grade):
            return

        if course not in lecturer.grades:
            lecturer.grades[course] = []
        lecturer.grades[course].append(grade)
        lecturer.set_avg_grade()

class Mentor:
    '''Базовый класс преподавателей'''

    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def __eq__(self, other):
        if sorted(self.courses_attached) == sorted(other.courses_attached):
            return True
        else:
            return False

    def set_courses_attached(self, courses_attached):
        if type(courses_attached) == list:
            self.courses_attached = courses_attached
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список закрепленных курсов: {courses_attached}')

class Lecturer(Mentor):
    '''Класс лекторов'''

    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}
        self.avg_grade = -1

    def __str__(self):
        msg = f'''Имя: {self.name}
Фамилия: {self.surname}
Средняя оценка за лекции: {round(self.avg_grade, 2)}'''
        return msg

    def __bool__(self):
        if (self.avg_grade == -1) or (self.avg_grade >= 3):
            return True
        else:
            return False

    def __add__(self, other):
        return self.avg_grade + other.avg_grade

    def __len__(self):
        k_grades = calc_k_grades(self.grades)
        return k_grades

    def set_avg_grade(self):
        self.avg_grade = calc_avg_grade(self.grades)


class Reviewer(Mentor):
    '''Класс проверяющих'''

    def __init__(self, name, surname):
        super().__init__(name, surname)

    def __str__(self):
        msg = f'''Имя: {self.name}
Фамилия: {self.surname}'''
        return msg

    def __bool__(self):
        if len(self.courses_attached) > 0:
            return True
        else:
            return False

    def __add__(self, other):
        return sorted(set(self.courses_attached + other.courses_attached))

    def __len__(self):
        return len(self.courses_attached)

    def rate_hw(self, student, course, grade):
        if not( (course in self.courses_attached) and (course in student.courses_in_progress) ):
            raise ValueError(f'❌ Ошибка: Невозможно поставить оценку по курсу: {course}')
        check_grade(grade)

        if course not in student.grades:
            student.grades[course] = []
        student.grades[course].append(grade)
        student.set_avg_grade()

# %% [markdown]
# ### **3.4. Тестирование**
#
# Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# * для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# * для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
def check_grade(grade) -> bool:
    '''Функция проверяет значение оценки на корректность'''

    try:
        if not(1 <= grade <= 10):
            raise ValueError(f'❌ Ошибка: Оценка должна находиться в пределах [1 10]: {grade}')
    except TypeError:
        raise TypeError(f'❌ Ошибка: Оценка не является числом: {grade}')

    return True

def calc_avg_grade(grades: dict):
    '''Функция вычисляет среднее арифмитическое оценок
    :return avg_grade: Возвращает среднее арифмитическое оценок'''

    if grades:
        grades_ll = list(grades.values())
        avg_grade = sum( sum(grade_l) for grade_l in grades_ll ) / sum( len(grade_l) for grade_l in grades_ll )
    else:
        avg_grade = -1

    return avg_grade

def calc_k_grades(grades: dict) -> int:
    '''Функция вычисляет количество оценок
    :return k_grades: Возвращает количество оценок'''

    grades_ll = list(grades.values())
    k_grades = sum( len(grade_l) for grade_l in grades_ll )

    return k_grades

def calc_st_avg_grade_many(l_students: list, course: str) -> float:
    '''Функция вычисляет среднее арифмитическое оценок по курсу у студентов'''

    grades = []
    for student in l_students:
        if type(student).__name__ != 'Student':
            raise TypeError(f'❌ Ошибка: Объект не принадлежит к классу студентов: {type(student).__name__}')
        if course in student.grades:
            grades.extend(student.grades[course])

    if len(grades) == 0:
        raise ValueError(f'❌ Ошибка: Оценки по курсу \"{course}\" отсутствуют')

    return sum(grades) / len(grades)

def calc_lec_avg_grade_many(l_lectors: list, course: str) -> float:
    '''Функция вычисляет среднее арифмитическое оценок по курсу у лекторов'''

    grades = []
    for lector in l_lectors:
        if type(lector).__name__ != 'Lecturer':
            raise TypeError(f'❌ Ошибка: Объект не принадлежит к классу лекторов: {type(lector).__name__}')
        if course in lector.grades:
            grades.extend(lector.grades[course])

    if len(grades) == 0:
        raise ValueError(f'❌ Ошибка: Оценки по курсу \"{course}\" отсутствуют')

    return sum(grades) / len(grades)


class Student:
    '''Класс студентов'''

    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.courses_in_progress = []
        self.finished_courses = []
        self.grades = {}
        self.avg_grade = -1

    def __str__(self):
        msg = f'''Имя: {self.name}
Фамилия: {self.surname}
Средняя оценка за домашние задания: {round(self.avg_grade, 2)}
Курсы в процессе изучения: {( ', '.join(self.courses_in_progress) ).strip()}
Завершенные курсы: {( ', '.join(self.finished_courses) ).strip()}'''
        return msg

    def __bool__(self):
        k_grades = calc_k_grades(self.grades)
        if (k_grades >= 10) and (self.avg_grade >= 6):
            return True
        else:
            return False

    def __eq__(self, other):
        if ( sorted(self.courses_in_progress) == sorted(other.courses_in_progress) ) \
        and ( sorted(self.finished_courses) == sorted(other.finished_courses) ):
            return True
        else:
            return False

    def __add__(self, other):
        return self.avg_grade + other.avg_grade

    def __len__(self):
        k_grades = calc_k_grades(self.grades)
        return k_grades

    def set_courses_in_progress(self, courses_in_progress):
        if type(courses_in_progress) == list:
            self.courses_in_progress = courses_in_progress
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список курсов в процессе обучения: {courses_in_progress}')

    def set_finished_courses(self, finished_courses):
        if type(finished_courses) == list:
            self.finished_courses = finished_courses
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список завершенных курсов: {finished_courses}')

    def set_avg_grade(self):
        self.avg_grade = calc_avg_grade(self.grades)

    def finish_course(self, course_name):
        if course_name in self.courses_in_progress:
            self.courses_in_progress.remove(course_name)
            self.finished_courses.append(course_name)
        else:
            raise ValueError(f'❌ Ошибка: Невозможно добавить завершенный курс: {course_name}')

    def rate_lecturer(self, lecturer, course, grade):
        if not( (course in lecturer.courses_attached) and (course in self.courses_in_progress) ):
            raise ValueError(f'❌ Ошибка: Невозможно поставить оценку по курсу: {course}')
        if not check_grade(grade):
            return

        if course not in lecturer.grades:
            lecturer.grades[course] = []
        lecturer.grades[course].append(grade)
        lecturer.set_avg_grade()

class Mentor:
    '''Базовый класс преподавателей'''

    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def __eq__(self, other):
        if sorted(self.courses_attached) == sorted(other.courses_attached):
            return True
        else:
            return False

    def set_courses_attached(self, courses_attached):
        if type(courses_attached) == list:
            self.courses_attached = courses_attached
        else:
            raise TypeError(f'❌ Ошибка: Невозможно обновить список закрепленных курсов: {courses_attached}')

class Lecturer(Mentor):
    '''Класс лекторов'''

    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}
        self.avg_grade = -1

    def __str__(self):
        msg = f'''Имя: {self.name}
Фамилия: {self.surname}
Средняя оценка за лекции: {round(self.avg_grade, 2)}'''
        return msg

    def __bool__(self):
        if (self.avg_grade == -1) or (self.avg_grade >= 6):
            return True
        else:
            return False

    def __add__(self, other):
        return self.avg_grade + other.avg_grade

    def __len__(self):
        k_grades = calc_k_grades(self.grades)
        return k_grades

    def set_avg_grade(self):
        self.avg_grade = calc_avg_grade(self.grades)


class Reviewer(Mentor):
    '''Класс проверяющих'''

    def __init__(self, name, surname):
        super().__init__(name, surname)

    def __str__(self):
        msg = f'''Имя: {self.name}
Фамилия: {self.surname}'''
        return msg

    def __bool__(self):
        if len(self.courses_attached) > 0:
            return True
        else:
            return False

    def __add__(self, other):
        return sorted(set(self.courses_attached + other.courses_attached))

    def __len__(self):
        return len(self.courses_attached)

    def rate_hw(self, student, course, grade):
        if not( (course in self.courses_attached) and (course in student.courses_in_progress) ):
            raise ValueError(f'❌ Ошибка: Невозможно поставить оценку по курсу: {course}')
        check_grade(grade)

        if course not in student.grades:
            student.grades[course] = []
        student.grades[course].append(grade)
        student.set_avg_grade()


lecturer1 = Lecturer('Мария', 'Петрова')
lecturer1.set_courses_attached(['Высшая математика', 'Математический анализ', 'Линейная алгебра и аналитическая геометрия', 'Теория вероятностей и математическая статистика'])

lecturer2 = Lecturer('Елена', 'Васильева')
lecturer2.set_courses_attached(['Математический анализ', 'Теория вероятностей и математическая статистика', 'Химия', 'Философия', 'Молодежная политика'])

student1 = Student('Иван', 'Соколов', 'M')
student1.set_courses_in_progress(['Математический анализ', 'Высшая математика', 'Страхование', 'Культурология', 'Конфликтология'])
student1.set_finished_courses(['Биология', 'Картография', 'Социология', 'Экология', 'Логистика'])
student1.rate_lecturer(lecturer1, 'Высшая математика', 10)
student1.rate_lecturer(lecturer1, 'Высшая математика', 8)
student1.rate_lecturer(lecturer2, 'Математический анализ', 2)
student1.rate_lecturer(lecturer2, 'Математический анализ', 4)

student2 = Student('Владимир', 'Зайцев', 'M')
student2.set_courses_in_progress(['Математический анализ', 'Философия', 'Маркетинг', 'Лингвистика', 'Конфликтология'])
student2.set_finished_courses(['Геология', 'Картография', 'Базы данных', 'Генетика', 'Инженерная графика'])
student2.rate_lecturer(lecturer1, 'Математический анализ', 7)
student2.rate_lecturer(lecturer1, 'Математический анализ', 6)
student2.rate_lecturer(lecturer2, 'Философия', 3)
student2.rate_lecturer(lecturer2, 'Философия', 4)

reviewer1 = Reviewer('Павел', 'Семёнов')
reviewer1.set_courses_attached(['Конфликтология', 'Теория государства и права', 'Страхование', 'Гидрология'])
reviewer1.rate_hw(student1, 'Страхование', 4)
reviewer1.rate_hw(student1, 'Страхование', 7)
reviewer1.rate_hw(student1, 'Конфликтология', 5)
reviewer1.rate_hw(student1, 'Конфликтология', 8)

reviewer2 = Reviewer('Николай', 'Тихонов')
reviewer2.set_courses_attached(['Конфликтология', 'Политология', 'Маркетинг'])
reviewer2.rate_hw(student2, 'Маркетинг', 7)
reviewer2.rate_hw(student2, 'Маркетинг', 9)
reviewer2.rate_hw(student2, 'Конфликтология', 3)
reviewer2.rate_hw(student2, 'Конфликтология', 4)


print('Класс \"Student\"')
print('-'*50)
print('__str__:\n' + str(student1) + '\n')
print(f'__bool__ (1): {bool(student1)}')
for _ in range(10):
    reviewer1.rate_hw(student1, 'Конфликтология', 8)
print(f'__bool__ (2): {bool(student1)}')
print(f'__eq__ (1): {student1 == student1}')
print(f'__eq__ (2): {student1 == student2}')
print(f'__add__: {student1 + student2}')
print(f'__len__: {len(student1)}')
student1.grades = {'Математический анализ': [8, 6, 7], 'Высшая математика': [7, 8], 'Конфликтология': [3, 4]}
print(f'avg_grade до: {student1.avg_grade}')
print(f'set_avg_grade: {student1.set_avg_grade()}')
print(f'avg_grade после: {student1.avg_grade}')
print(f'finished_courses до: {student1.finished_courses}')
print(f'finish_course: {student1.finish_course('Страхование')}')
print(f'finished_courses после: {student1.finished_courses}')
print(f'-'*50)

print('\nКласс \"Mentor\"')
print('-'*50)
print(f'__eq__ (1): {lecturer1 == lecturer1}')
print(f'__eq__ (2): {reviewer1 == reviewer2}')
print('-'*50)

print('\nКласс \"Lecturer\"')
print('-'*50)
print('__str__:\n' + str(lecturer1) + '\n')
print(f'__bool__ (1): {bool(lecturer1)}')
print(f'__bool__ (2): {bool(lecturer2)}')
print(f'__add__: {lecturer1 + lecturer2}')
print(f'__len__: {len(lecturer1)}')
lecturer1.grades = {'Математический анализ': [3, 7], 'Высшая математика': [5, 6, 8], 'Теория вероятностей и математическая статистика': [6, 4]}
print(f'avg_grade до: {lecturer1.avg_grade}')
print(f'set_avg_grade: {lecturer1.set_avg_grade()}')
print(f'avg_grade после: {lecturer1.avg_grade}')
print('-'*50)

print('\nКласс \"Reviewer\"')
print('-'*50)
print('__str__:\n' + str(reviewer1) + '\n')
print(f'__bool__ (1): {bool(reviewer1)}')
reviewer1.set_courses_attached([])
print(f'__bool__ (2): {bool(reviewer1)}')
reviewer1.set_courses_attached(['Конфликтология', 'Теория государства и права', 'Страхование', 'Гидрология'])
print(f'__add__: {reviewer1 + reviewer2}')
print(f'__len__: {len(reviewer1)}')
print('-'*50)


print(f'\ncalc_st_avg_grade_many: {calc_st_avg_grade_many([student1, student2], 'Математический анализ')}')
print(f'calc_lec_avg_grade_many: {calc_lec_avg_grade_many([lecturer1, lecturer2], 'Математический анализ')}')
# Out:
# Класс "Student"
# --------------------------------------------------
# __str__:
# Имя: Иван
# Фамилия: Соколов
# Средняя оценка за домашние задания: 6.0
# Курсы в процессе изучения: Математический анализ, Высшая математика, Страхование, Культурология, Конфликтология
# Завершенные курсы: Биология, Картография, Социология, Экология, Логистика
#
# __bool__ (1): False
# __bool__ (2): True
# __eq__ (1): True
# __eq__ (2): False
# __add__: 13.178571428571429
# __len__: 14
# avg_grade до: 7.428571428571429
# set_avg_grade: None
# avg_grade после: 6.142857142857143
# finished_courses до: ['Биология', 'Картография', 'Социология', 'Экология', 'Логистика']
# finish_course: None
# finished_courses после: ['Биология', 'Картография', 'Социология', 'Экология', 'Логистика', 'Страхование']
# --------------------------------------------------
#
# Класс "Mentor"
# --------------------------------------------------
# __eq__ (1): True
# __eq__ (2): False
# ...

# %% [markdown]
# ## **Задание №4. Перегрузка операторов с помощью магических методов**

# %% [markdown]
# ### **Цель задания:**

# %% [markdown]
# Разработать класс `Fraction` для работы с рациональными числами (дробями), реализовав перегрузку стандартных операторов через переопределение соответствующих магических методов. Ваша задача — обеспечить класс `Fraction` функциональностью, демонстрируемой в приведенном примере кода.

# %% [markdown]
# ### **Описание задания:**

# %% [markdown]
# Создайте класс `Fraction`, который представляет собой обыкновенную дробь с числителем и знаменателем. Перегрузите основные арифметические операторы для выполнения операций над дробями, а также операторы сравнения. Обеспечьте возможность преобразования дроби в число с плавающей точкой и обратную операцию. Реализуйте обработку исключений при некорректных данных. Предоставьте понятное строковое и официальное представление дроби.

# %% [markdown]
# **Требования к заданию:**

# %% [markdown]
# 1. **Класс `Fraction` должен:**
#
#    - Инициализироваться двумя целыми числами: числителем и знаменателем.
#    - Обрабатывать ситуацию когда знаменатель равен нулю, а именно выводить сообщение `"Знаменатель не может быть нулем"`.
#    - Упрощать дроби до несократимых при создании и после каждой арифметической операции.
#
# 2. **Перегрузить следующие операторы путем переопределения магических методов:**
#
#    - **Сложение `+`** (`__add__`): сложение двух дробей, возвращает новую дробь.
#    - **Вычитание `-`** (`__sub__`): вычитание одной дроби из другой, возвращает новую дробь.
#    - **Умножение `*`** (`__mul__`): умножение двух дробей, возвращает новую дробь.
#    - **Деление `/`** (`__truediv__`): деление одной дроби на другую, возвращает новую дробь.
#    - **Равенство `==`** (`__eq__`): проверка равенства двух дробей.
#    - **Сравнения `>`, `<`, `>=`, `<=`**: сравнение дробей по их значению, реализовать методы `__lt__`, `__le__`, `__gt__`, `__ge__`.
#
# 3. **Реализовать преобразование типов:**
#
#    - **Метод `__float__`**: преобразование дроби в число с плавающей точкой.
#
# 4. **Дополнительные методы класса:**
#
#    - **`reciprocal()`**: возвращает новую дробь, обратную данной (числитель и знаменатель меняются местами).
#    - **Строковое представление** (`__str__`): возвращает строку вида `"числитель/знаменатель"`. Если знаменатель равен 1, возвращает только числитель в виде строки.
#    - **Официальное представление** (`__repr__`): возвращает строку вида `"Fraction(числитель, знаменатель)"`.
#
# 5. **Обработка исключений:**
#
#    - При попытке создать дробь с нулевым знаменателем выводить в консоль сообщение `ValueError`.
#    - При попытке деления на нулевую дробь, выводить в консоль сообщение `ZeroDivisionError`.
#
# 6. **Тестирование:**
#
#    - Написать код, демонстрирующий работу всех реализованных методов и операторов, используя примеры, приведенные ниже.
#    - Обеспечить корректную обработку исключений и вывод соответствующих сообщений.

# %%
def shorten(numerator: int, denominator: int) -> tuple:
    '''Функция сокращает дробь
    :return numerator: Возвращает сокращенный числитель
    :return denominator: Возвращает скоращенный знаменатель'''

    from math import gcd

    common = gcd(numerator, denominator)
    numerator //= common
    denominator //= common

    return numerator, denominator

def to_common_denominator(self, other) -> tuple:
    '''Функция приводит две дроби к общему знаменателю
    :return self_numerator: Возвращает приведенный делитель первой дроби
    :return other_numerator: Возвращает приведенный делитель второй дроби
    :return denominator: Возвращает приведенный знаменатель двух дробей'''

    from math import lcm

    common = lcm(self.denominator, other.denominator)
    mult_1 = common // self.denominator
    mult_2 = common // other.denominator
    self_numerator = self.numerator * mult_1
    other_numerator = other.numerator * mult_2
    denominator = common

    return self_numerator, other_numerator, denominator


class Fraction:
    '''Класс дробей'''

    def __init__(self, numerator, denominator):
        if int(numerator) == numerator:
            numerator = int(numerator)
        if int(denominator) == denominator:
            denominator = int(denominator)
        if type(numerator) != int:
            raise TypeError(f'❌ Ошибка: Числитель не является целым числом : {numerator}')
        if type(denominator) != int:
            raise TypeError(f'❌ Ошибка: Знаменатель не является целым числом: {denominator}')
        if denominator == 0:
            raise ValueError('❌ Ошибка: Знаменатель не может быть нулем')

        self.numerator, self.denominator = shorten(numerator, denominator)

    def __str__(self):
        if self.denominator == 1:
            return str(self.numerator)
        else:
            return f'{self.numerator}/{self.denominator}'

    def __repr__(self):
        return f'Fraction({self.numerator}, {self.denominator})'

    def __add__(self, other):
        self_numerator, other_numerator, denominator = to_common_denominator(self, other)
        numerator = self_numerator + other_numerator
        return Fraction(numerator, denominator)

    def __sub__(self, other):
        self_numerator, other_numerator, denominator = to_common_denominator(self, other)
        numerator = self_numerator - other_numerator
        return Fraction(numerator, denominator)

    def __mul__(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        return Fraction(numerator, denominator)

    def __truediv__(self, other):
        if other.numerator == 0:
            raise ZeroDivisionError('❌ Ошибка: Числитель делимого не может быть нулем')
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Fraction(numerator, denominator)

    def __eq__(self, other):
        if (self.numerator == other.numerator) and (self.denominator == other.denominator):
            return True
        else:
            return False

    def __lt__(self, other):
        self_numerator, other_numerator, denominator = to_common_denominator(self, other)
        if self_numerator < other_numerator:
            return True
        else:
            return False

    def __le__(self, other):
        self_numerator, other_numerator, denominator = to_common_denominator(self, other)
        if self_numerator <= other_numerator:
            return True
        else:
            return False

    def __gt__(self, other):
        self_numerator, other_numerator, denominator = to_common_denominator(self, other)
        if self_numerator > other_numerator:
            return True
        else:
            return False

    def __ge__(self, other):
        self_numerator, other_numerator, denominator = to_common_denominator(self, other)
        if self_numerator >= other_numerator:
            return True
        else:
            return False

    def __float__(self):
        return self.numerator / self.denominator

    @classmethod
    def from_float(cls, value):
        if type(value) not in [int, float]:
            raise TypeError(f'❌ Ошибка: Введенное значение не является числом : {value}')
        denominator = 10**9
        numerator = int(value * denominator)
        numerator, denominator = shorten(numerator, denominator)
        return cls(numerator, denominator)

    def reciprocal(self):
        return Fraction(self.denominator, self.numerator)

# %% [markdown]
# **Тесты для класса `Fraction`:**

# %%
# Создание дробей
f1 = Fraction(3, 4)
f2 = Fraction(5, 6)

# Сложение дробей
f3 = f1 + f2
print(f3)  # Ожидаемый вывод: 19/12

# Вычитание дробей
f4 = f1 - f2
print(f4)  # Ожидаемый вывод: -1/12

# Умножение дробей
f5 = f1 * f2
print(f5)  # Ожидаемый вывод: 5/8

# Деление дробей
f6 = f1 / f2
print(f6)  # Ожидаемый вывод: 9/10

# Проверка равенства
print(f1 == Fraction(6, 8))   # Ожидаемый вывод: True

# Сравнение дробей
print(f1 > f2)    # Ожидаемый вывод: False
print(f1 < f2)    # Ожидаемый вывод: True

# Преобразование к float
print(float(f1))  # Ожидаемый вывод: 0.75

# Обратная дробь
f7 = f1.reciprocal()
print(f7)         # Ожидаемый вывод: 4/3

# Создание дроби из float
f8 = Fraction.from_float(0.75)
print(f8)         # Ожидаемый вывод: 3/4

# Проверка обработки исключений
try:
    f_invalid = Fraction(5, 0)
except ValueError as e:
    print(e)  # Ожидаемый вывод: Знаменатель не может быть нулем

# Строковое и официальное представление
print(str(f1))    # Ожидаемый вывод: 3/4
print(repr(f1))   # Ожидаемый вывод: Fraction(3, 4)
# Out:
# 19/12
# -1/12
# 5/8
# 9/10
# True
# False
# True
# 0.75
# 4/3
# 3/4
# ❌ Ошибка: Знаменатель не может быть нулем
# 3/4
# Fraction(3, 4)
